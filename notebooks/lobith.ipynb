# %%
import xarray as xr

# %%
ds = xr.open_dataset('/Users/baart_f/data/drought/rws/id29-LOBH.nc')

# %%
ds['time']
# Out:
# <xarray.DataArray 'time' (time: 10592)>
# array(['1988-12-31T23:00:00.000000000', '1989-01-01T23:00:00.000000000',
#        '1989-01-02T23:00:00.000000000', ..., '2017-12-28T23:00:00.000000000',
#        '2017-12-29T23:00:00.000000000', '2017-12-30T23:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 1988-12-31T23:00:00 ... 2017-12-30T23:00:00
# Attributes:
#     long_name:      time
#     standard_name:  time
